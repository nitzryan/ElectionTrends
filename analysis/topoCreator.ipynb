# %%
import json
import geopandas as gpd
from topojson import Topology

# %%
gdf = gpd.read_file('maps/ak.shp')
gdf = gdf.to_crs(epsg=4326)
gdf.to_file("maps/AK.json", driver='GeoJSON')
# Out:
#    STATEFP SLDLST         GEOIDFQ  GEOID NAME                 NAMELSAD STUSPS  \
# 0       02    039  620L800US02039  02039   39  State House District 39     AK
# 1       02    009  620L800US02009  02009    9   State House District 9     AK
# 2       02    017  620L800US02017  02017   17  State House District 17     AK
# 3       02    038  620L800US02038  02038   38  State House District 38     AK
# 4       02    035  620L800US02035  02035   35  State House District 35     AK
# 5       02    019  620L800US02019  02019   19  State House District 19     AK
# 6       02    003  620L800US02003  02003    3   State House District 3     AK
# 7       02    006  620L800US02006  02006    6   State House District 6     AK
# 8       02    036  620L800US02036  02036   36  State House District 36     AK
# 9       02    001  620L800US02001  02001    1   State House District 1     AK
# 10      02    025  620L800US02025  02025   25  State House District 25     AK
# ...
